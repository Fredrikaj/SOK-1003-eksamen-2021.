# %%
#Denne oppgaven er intressant for oss fordi vi ønsker og se hvordan beløpet endrer seg etter man har lånt penger av banken.
#Å hvordan den endre seg med årlige innbetalinger dette skjer også ved bruk av annuitetprinsippet da den første tilbakebetalingen skal skje ett år etter låneopptak.



#kildene vi har brukt her er modul 42 i matte pensumet. Dette er et kjent låne prinsipp alle bankene i norge annbefaler. 
#Denne låne metoden er at du betaler det samme beløpet hver måned gjennom hele løpetiden til lånet, gitt at renten er uforandret, og etterhvert blir renteandelen mindre og avdragsdelen høyere.

#i denne oppgaven har vi valgt og brukt en kalkulator inne i python for å kunne berengde beløpet man betaler tilbake hvert år og i denne kalkulatoren er det forskjellige faktorer som kan spille inn.
#som for eksempel om man har barn,bil eller andre lån.

# med k0=650 000, r=0.04 og n = 12 får vi at 

#K = K0 x 0.04x1.04^12/1.04^12-1 = 69259 er beløpet som må betales inn hver termin. da kunne vi også finne hva dem måtte betale totalt tilbake som hvar 69259x12= 831 108 totalt tilbake til banken.

#dette er da hvordan man berengner hvor mye man må betale tilbake hver termin og den totale summen tilslutt. 



import numpy as np


def kalkulator():
years = np.array([12])
tp = np.array([650000]) ## terminbeløp
print("Please insert amount to loan")
loan = int(input(400000))
print("Please insert termin in years")
y = int(input(12))
print("please insert deductible")
egen = int(input(150000))
print("please insert number of kids")
kids = int(input(4))
print("Do you have car?")
car = int(input(2))
print("Do you have any debt?")
debt = int(input(2500000))

#### renta!
nr= 1.1

##### making a time referance line to calculate interest
tid_years = np.array([])
renta = ([])
extra = ([])## new array for interest in case you have kids/car

for i in range(y):
tid_years = np.append(tid_years, i)
print(tid_years)

#### preparing intereset in relation with year (take a look to tid_years)
for x in tid_years:
renta = np.append(renta, nr**x)
print(renta)

#### in case you have kids or/and car
if kids ==1 and car ==1:
for g in renta:
extra = np.append(extra, g*1.003)
return extra

elif kids >1: ### do you have more than 1 child?
for f in renta:
extra = np.append(extra, f*1.005)
return extra
